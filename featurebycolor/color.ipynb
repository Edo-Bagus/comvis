# %%
import sys
import os

# Add the absolute path to the utils folder
sys.path.append(os.path.abspath('../'))

from utils import colors
from utils import eda

# %%
eda.display_images('../datasets', n=15, random_state=42)

# %%
colors.process_all_image_features('../datasets', 'color_features.csv')
# Out:
# ✅ Semua fitur berhasil digabung dan disimpan: color_features.csv

# %%
colors.process_all_image_features('../Dataset_aug/train', 'color_train.csv')
colors.process_all_image_features('../Dataset_aug/train_aug', 'color_train_aug.csv')
colors.process_all_image_features('../Dataset_aug/test', 'color_test.csv')
